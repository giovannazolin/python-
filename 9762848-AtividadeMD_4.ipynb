# %% [markdown]
# # Atividade: Agrupamento de Dados

# %% [markdown]
# Giovanna Zolin Pinheiro Hayasida - n:9762848

# %% [markdown]
# 1.Baixar a base de dados que foi disponibilizada na atividade, entender como ela está estruturada, e fazer a leitura dos dados.

# %%
#Importando pacotes
import random
random.seed(1)
import pandas as pd
import matplotlib.pyplot as plt

#Lendo o arquivo CSV com os dados
data = pd.read_csv('words_data.csv', header= None)
data.head(5)
# Out:
#      0         1         2         3         4         5         6    \
# 0    car  0.130859  0.008423  0.033447 -0.058838  0.040039 -0.142578
# 1    bus  0.059326 -0.169922  0.038818 -0.049561  0.038330 -0.153320
# 2  drive -0.025879  0.097656  0.008972 -0.097656 -0.122070 -0.103516
# 3   road  0.111816  0.263672  0.085938 -0.083984  0.146484 -0.031738
# 4  devil  0.287109 -0.186523  0.161133  0.182617 -0.174805  0.367188
#
#         7         8         9      ...          291       292       293  \
# 0  0.049316 -0.168945  0.208984    ...    -0.275391  0.285156 -0.047363
# 1 -0.166016 -0.443359  0.239258    ...    -0.011108  0.079590  0.130859
# 2  0.030762 -0.167969 -0.006622    ...    -0.011780  0.380859 -0.181641
# 3 -0.194336 -0.261719 -0.000030    ...    -0.050781  0.035156 -0.292969
# 4 -0.018677 -0.026978  0.125977    ...    -0.005371 -0.064941 -0.093262
#
#         294       295       296       297       298       299       300
# ...

# %% [markdown]
# 2. Agrupar os dados por meio do algoritmo de agrupamento K-Means. Um dos parâmetros desse algoritmo é número de grupos a serem gerados. Escolha 3 grupos.

# %%
import numpy as np
#Listando nomes das colunas
list_labels = list(data.columns)

#Selecionando a coluna contendo as classes e armazenando em Y.
Y = np.array(data[list_labels[0]],dtype=str)

#Retirando a coluna com as classes de data e armazenando em X.
data= data.drop(list_labels[0], axis = 1)

#Salvando os nomes das características para uso posterior.
data_list = list(data.columns)

#Convertando num numpy array
X = np.array(data)

# %%
from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters=3)

# %%
kmeans.fit(X)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#     n_clusters=3, n_init=10, n_jobs=None, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=0)

# %%
print(kmeans.cluster_centers_)
# save new clusters for chart
y_km = kmeans.fit_predict(X)
# Out:
# [[ 2.08740235e-01  8.05663875e-03  1.62353515e-01  8.89892590e-02
#   -2.06947331e-02  1.57928466e-01 -2.75573740e-02 -1.61834716e-01
#    1.38793944e-01  2.06542970e-01  8.33129895e-02 -1.76269532e-01
#   -1.50268557e-01  1.33252132e-02 -1.69799806e-01  2.88085963e-02
#    2.79235840e-02  5.14221205e-02  6.65893550e-02 -1.25427244e-01
#    8.50830090e-02 -1.40380870e-02 -2.92968750e-02 -4.97436515e-02
#   -2.70614630e-02  9.00878925e-02  4.68444725e-03 -9.76562488e-02
#    1.36779786e-01 -2.70385743e-01 -3.94549376e-02  1.53381348e-01
#    4.77218635e-02  5.21240240e-02 -4.09927359e-02 -7.74765025e-03
#    1.34094239e-01 -1.22650143e-01 -1.22802732e-01  2.23388672e-01
#    1.71508790e-01 -1.20971680e-01  2.32360841e-01 -4.03747583e-02
#   -4.66308575e-02  6.29882805e-02  5.56640625e-02 -9.34600830e-02
#   -4.43725580e-02  4.13818381e-02 -2.22900393e-01  2.58178715e-01
#    7.73925770e-02 -5.79833975e-02  8.90808105e-02 -1.42578125e-01
# ...

# %% [markdown]
# 3. Mostrar como as palavras foram agrupadas (quais palavras ficaram juntas e quais ficaram separadas), e analisar se esse agrupamento faz sentido considerando o significado das palavras.

# %%
cluster_map = pd.DataFrame()
cluster_map['data_index'] = Y
cluster_map['cluster'] = kmeans.labels_
cluster_map
# Out:
#    data_index  cluster
# 0         car        2
# 1         bus        2
# 2       drive        2
# 3        road        2
# 4       devil        0
# 5        fire        2
# 6        hell        0
# 7        dead        0
# 8        dark        0
# 9        golf        1
# 10     sports        1
# 11     racing        1
# 12    circuit        2
# 13     soccer        1
# 14       game        1
# 15      rugby        1

# %% [markdown]
# O cluster 0 está relacionado. O 1 possui palavras relacionadas com esportes. E o 2 trata de palavras referentes a transporte, com a ressalva da palavra 'fire', que talvez poderia estar relacionada com o cluster 0.

# %% [markdown]
# 4. Agrupar os dados utilizando um algoritmo de agrupamento hierárquico.

# %%
import scipy.cluster.hierarchy as hac
z = hac.linkage(X, method='single',metric='euclidean')

# %% [markdown]
# 5. Plotar o dendrograma resultante do agrupamento hierárquico. A partir do dendrograma obtido, analisar o resultado como na etapa (3). Considerar 3 grupos nessa análise.

# %%
fig = plt.figure(figsize=(25, 10))
dn = dendrogram(z, labels = Y, color_threshold = 3.085)
plt.show()

# %% [markdown]
# O grupo em azul possui mais palavras do mesmo conceito de 'dark', por exemplo, mas possui palavras que não se encaixam como 'rugby'. O grupo verde tem majoritariamente as palavras sobre automóveis, mas 'game' não está no contexto, sendo uma palavra intrusa. O grupo vermelho parece ser o mais bem formado, com palavras relacionadas a esportes.
